# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Import File

# %%
path = "C:\\CSE\\Chirag-Rao-KV\\Task 3.2\\Threats (1).csv"
df = pd.read_csv(path)
df
# Out:
#         Unnamed: 0      id       dur proto service state  spkts  dpkts  \
# 0            40000   40001  0.012996   tcp       -   FIN     16     18
# 1            40001   40002  0.004119   tcp       -   FIN     12     12
# 2            40002   40003  0.000988   udp     dns   CON      2      2
# 3            40003   40004  3.415787   tcp     ssh   FIN    230    238
# 4            40004   40005  0.193943   tcp       -   FIN     72     74
# ...            ...     ...       ...   ...     ...   ...    ...    ...
# 135336      175336  175337  0.000009   udp     dns   INT      2      0
# 135337      175337  175338  0.505762   tcp       -   FIN     10      8
# 135338      175338  175339  0.000009   udp     dns   INT      2      0
# 135339      175339  175340  0.000009   udp     dns   INT      2      0
# 135340      175340  175341  0.000009   udp     dns   INT      2      0
#
#         sbytes  dbytes  ...  ct_dst_sport_ltm  ct_dst_src_ltm  is_ftp_login  \
# 0         1540    1644  ...                 1               6             0
# 1         1064    2260  ...                 1               1             0
# 2          146     178  ...                 1               2             0
# 3        24344   29556  ...                 1               1             0
# 4         4238   63618  ...                 1               5             0
# ...        ...     ...  ...               ...             ...           ...
# 135336     114       0  ...                13              24             0
# 135337     620     354  ...                 1               2             0
# 135338     114       0  ...                 3              13             0
# 135339     114       0  ...                14              30             0
# 135340     114       0  ...                16              30             0
#
#         ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  is_sm_ips_ports  \
# 0                0                 0           5           7                0
# 1                0                 0           3           8                0
# 2                0                 0           7           2                0
# 3                0                 0           4           1                0
# 4                0                 0           6          12                0
# ...            ...               ...         ...         ...              ...
# 135336           0                 0          24          24                0
# 135337           0                 0           1           1                0
# 135338           0                 0           3          12                0
# 135339           0                 0          30          30                0
# 135340           0                 0          30          30                0
#
#         attack_cat  label
# 0           Normal      0
# 1           Normal      0
# 2           Normal      0
# 3           Normal      0
# 4           Normal      0
# ...            ...    ...
# 135336     Generic      1
# 135337   Shellcode      1
# 135338     Generic      1
# 135339     Generic      1
# 135340     Generic      1
#
# [135341 rows x 46 columns]

# %% [markdown]
# Drop the duplicate rows

# %%
columns_drop = {'Unnamed: 0','id'}
df = df.drop(columns=columns_drop,errors='ignore')
df = df.drop_duplicates()

# %% [markdown]
# Exchange  'label' & 'attack_cat'

# %%
#exchange last two columns
col = [ 'dur', 'proto', 'service', 'state', 'spkts', 'dpkts', 'sbytes',
       'dbytes', 'rate', 'sttl', 'dttl', 'sload', 'dload', 'sloss', 'dloss',
       'sinpkt', 'dinpkt', 'sjit', 'djit', 'swin', 'stcpb', 'dtcpb', 'dwin',
       'tcprtt', 'synack', 'ackdat', 'smean', 'dmean', 'trans_depth',
       'response_body_len', 'ct_srv_src', 'ct_state_ttl', 'ct_dst_ltm',
       'ct_src_dport_ltm', 'ct_dst_sport_ltm', 'ct_dst_src_ltm',
       'is_ftp_login', 'ct_ftp_cmd', 'ct_flw_http_mthd', 'ct_src_ltm',
       'ct_srv_dst', 'is_sm_ips_ports',  'label','attack_cat']
df = df[col]

# %% [markdown]
# # Visualise the attack categories

# %%
from pywaffle import Waffle

# %%
category_counts = df['attack_cat'].value_counts()
category_counts = round(category_counts*100/(np.sum(category_counts)),3)
data = pd.DataFrame({'attack_cat': category_counts.index, 'count': category_counts.values})
data_sorted = data.sort_values(by='count', ascending=False)
plot_lable = [f'{i} ({str(j)} %)'for i,j in zip(data_sorted['attack_cat'], data_sorted['count'])]
colors = [
    "#FF5733", 
    "#33FF57",
    "#3357FF",  
    "#FFD133",  
    "#8D33FF",  
    "#FF33A8",  
    "#33FFF3", 
    "#FF8C33",  
    "#A833FF",
    "#57FF33"
]

# %% [markdown]
# It can be seen attack categories Analysis (2.331 %), Backdoor (2.244 %), Shellcode (1.595 %),Worms (0.186 %) have a very presence.

# %%
fig = plt.figure(
    FigureClass=Waffle,
    rows=5,  
    columns = 20,
    values=data['count'],  
    figsize=(11, 5),  
    colors = colors,
    labels=plot_lable,  
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)},  
    title={'label': "Attack Categories", 'loc': 'center'}  
)
# Out:
# <Waffle size 1100x500 with 1 Axes>

# %% [markdown]
# # Ordinal Encoding
# Assigning unique value to each category

# %%
from sklearn.preprocessing import OrdinalEncoder


cat_col = df.select_dtypes(exclude=['number']).columns
cat_col = ['proto', 'service', 'state']
encoder = OrdinalEncoder()
df[cat_col] = encoder.fit_transform(df[cat_col])
df
# Out:
#              dur  proto  service  state  spkts  dpkts  sbytes  dbytes  \
# 0       0.012996  111.0      0.0    1.0     16     18    1540    1644
# 1       0.004119  111.0      0.0    1.0     12     12    1064    2260
# 2       0.000988  117.0      2.0    0.0      2      2     146     178
# 3       3.415787  111.0     11.0    1.0    230    238   24344   29556
# 4       0.193943  111.0      0.0    1.0     72     74    4238   63618
# ...          ...    ...      ...    ...    ...    ...     ...     ...
# 135267  1.914309  111.0      9.0    1.0     74     30   69997    2132
# 135277  3.719110  111.0      0.0    1.0     66    340    3086  426483
# 135299  0.996503  111.0      7.0    1.0     20     30     942   16684
# 135305  1.557125  111.0      9.0    1.0     28     22   12601    1954
# 135337  0.505762  111.0      0.0    1.0     10      8     620     354
#
#                rate  sttl  ...  ct_dst_sport_ltm  ct_dst_src_ltm  \
# 0       2539.242797    31  ...                 1               6
# 1       5583.879675    31  ...                 1               1
# 2       3036.437382    31  ...                 1               2
# 3        136.718127    31  ...                 1               1
# 4        747.642372    31  ...                 1               5
# ...             ...   ...  ...               ...             ...
# 135267    53.805315    62  ...                 1               1
# 135277   108.897021    62  ...                 1               1
# 135299    49.171955    62  ...                 1               1
# 135305    31.468251    62  ...                 1               2
# 135337    33.612649   254  ...                 1               2
#
#         is_ftp_login  ct_ftp_cmd  ct_flw_http_mthd  ct_src_ltm  ct_srv_dst  \
# 0                  0           0                 0           5           7
# 1                  0           0                 0           3           8
# 2                  0           0                 0           7           2
# 3                  0           0                 0           4           1
# 4                  0           0                 0           6          12
# ...              ...         ...               ...         ...         ...
# 135267             0           0                 0          18           1
# 135277             0           0                 0           2           1
# 135299             0           0                 0           7           1
# 135305             0           0                 0           2           1
# 135337             0           0                 0           1           1
#
#         is_sm_ips_ports  label  attack_cat
# 0                     0      0      Normal
# 1                     0      0      Normal
# 2                     0      0      Normal
# 3                     0      0      Normal
# 4                     0      0      Normal
# ...                 ...    ...         ...
# 135267                0      1    Exploits
# 135277                0      1    Exploits
# 135299                0      1    Exploits
# 135305                0      1    Exploits
# 135337                0      1   Shellcode
#
# [68391 rows x 44 columns]

# %% [markdown]
# # Split test train data

# %%
from sklearn.model_selection import train_test_split

feature = [col for col in df.columns if col != 'attack_cat']
x = df[feature]
y = df['attack_cat']
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.5, shuffle= True)

# %% [markdown]
# # Train decision tree

# %%
from sklearn import tree

# %%
classifier = tree.DecisionTreeClassifier()
classifier = classifier.fit(x_train,y_train)

# %% [markdown]
# # Confusion matrix

# %%
from sklearn.metrics import confusion_matrix

# %%
y_test_predict = classifier.predict(x_test) 
confu_matrix = confusion_matrix(y_test,y_test_predict)
categories_array = data['attack_cat']
plt.figure(figsize=(10, 8)) 
sns.heatmap(confu_matrix,xticklabels=categories_array,yticklabels=categories_array,cmap='Blues',annot=True)
plt.show()

# %% [markdown]
# # Evaluation of model

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,classification_report

# %%
print('For overall data')
accuracy = accuracy_score(y_test, y_test_predict)
print(f"Accuracy: {accuracy}")

precision = precision_score(y_test, y_test_predict,average='macro')
print(f"Precision: {precision}")


recall = recall_score(y_test, y_test_predict,average='macro')
print(f"Recall: {recall}")

f1 = f1_score(y_test, y_test_predict,average='macro')
print(f"F1 Score: {f1}")
print('\nFor each categories\n')
classification_report = classification_report(y_test,y_test_predict)
print(classification_report)
# Out:
# For overall data
# Accuracy: 0.7758509767224236
# Precision: 0.5932948168211559
# Recall: 0.5913232612731237
# F1 Score: 0.5893819300450438
#
# For each categories
#
#                 precision    recall  f1-score   support
#
#       Analysis       0.08      0.17      0.11       784
#       Backdoor       0.13      0.16      0.14       804
#            DoS       0.25      0.27      0.26      1881
#       Exploits       0.81      0.77      0.79      9960
#        Fuzzers       0.91      0.87      0.89      8015
#        Generic       0.89      0.84      0.86      2137
#         Normal       1.00      1.00      1.00      6264
# Reconnaissance       0.83      0.71      0.77      3747
#      Shellcode       0.60      0.59      0.59       531
#          Worms       0.45      0.52      0.48        73
#
#       accuracy                           0.78     34196
#      macro avg       0.59      0.59      0.59     34196
#   weighted avg       0.81      0.78      0.79     34196
